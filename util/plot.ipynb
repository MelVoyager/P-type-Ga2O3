# %%
from matplotlib import pyplot as plt
import matplotlib
a=sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])

with open('font.txt', "w") as f:
    for i in a:
        f.write(f'{i}\n')

# %% [markdown]
# 绘制一个关于原子个数N的收敛性图，测试使用哪个N更好

# %%
# 由于执行状态已重置，需要重新定义数据并绘图

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['Noto Sans CJK JP'] 
mpl.rcParams['font.size'] = 10  
mpl.rcParams['axes.unicode_minus'] = False 

# 重新定义数据
n_values = [40, 120, 160, 20]
energy_values = [-0.31866464E+03, -0.95832004E+03, -0.12749441E+04, -0.15854181E+03]

# 计算平均能量
average_energy_values = [energy / n for energy, n in zip(energy_values, n_values)]

# 按 n 排序数据
sorted_indices = sorted(range(len(n_values)), key=lambda i: n_values[i])
n_values = [n_values[i] for i in sorted_indices]
average_energy_values = [average_energy_values[i] for i in sorted_indices]

# 重新绘图
plt.figure(figsize=(6, 4))
plt.plot(n_values, average_energy_values, marker='o', linestyle='-', color='b', label="每个原子平均能量")

# 添加标签和标题
plt.xlabel("原子数n")
plt.ylabel("每个原子平均能量")
plt.title("每个原子平均能量——原子数n")
plt.legend()
plt.grid()

# 显示图像
plt.show()

# %% [markdown]
# 绘制一个关于KPoints k取值的收敛性图

# %%
# 重新定义数据
n_values = [1, 2, 4]
energy_values = [-.95751210E+03, -.95832004E+03, -.95876031E+03]

# 计算平均能量
average_energy_values = [energy / 120 for energy, n in zip(energy_values, n_values)]

# 按 n 排序数据
sorted_indices = sorted(range(len(n_values)), key=lambda i: n_values[i])
n_values = [n_values[i] for i in sorted_indices]
average_energy_values = [average_energy_values[i] for i in sorted_indices]

# 重新绘图
plt.figure(figsize=(6, 4))
plt.plot(n_values, average_energy_values, marker='o', linestyle='-', color='b', label="每个原子平均能量")

# 添加标签和标题
plt.xlabel("每个维度K点采样密度")
plt.ylabel("每个原子平均能量")
plt.title("每个原子平均能量——K点采样密度")
plt.legend()
plt.grid()

# 显示图像
plt.show()

# %% [markdown]
# N_O的电荷转变能级

# %%
# 数据准备
data = {
    r"N$_{O(I)}$": [4.09059E+00, 3.542],
    r"N$_{O(II)}$": [2.96169E+00, 2.599],
    r"N$_{O(III)}$": [3.90257E+00, 3.363]
}

# 图形参数设置
x_positions = [1, 2, 3]  # 每列在x轴上的位置
colors = ['#2F5597', '#ED7D31']  # 不同来源的颜色
labels = ['我们的计算结果', r'文献$^1$中的计算结果']  # 图例标签
column_width = 0.8  # 每列占据的宽度

plt.figure(figsize=(8, 6))
ax = plt.gca()

# 绘制横线
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 绘制两条能级线
    for i, value in enumerate(values):
        ax.hlines(y=value, 
                #  xmin=x_min + 0.05 + i*0.4,  # 横向偏移避免重叠
                #  xmax=x_max - 0.05 - (1-i)*0.4,
                xmin=x_min,
                xmax=x_max,
                 colors=colors[i], 
                 linewidth=3, 
                 label=labels[i] if idx == 0 else "")

# 坐标轴设置
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(2.5, 4.2)  # 设置Y轴范围

# 添加辅助网格
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 添加数据标签
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    for i, value in enumerate(values):
        ax.text(x_center - 0.15 + 0.3*i, 
               value + 0.05, 
               f"{value:.2f} eV", 
               ha='center',
               color=colors[i],
               fontsize=10)

# 美化边框
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# 绘制$P_O$电荷态转变能级

# %%
# 数据准备（仅保留第一个来源的数据）
data = {
    r"P$_{O(I)}$": [5.29231],  # 只保留第一个值
    r"P$_{O(II)}$": [4.32178], 
    r"P$_{O(III)}$": [4.47017]
}

# 图形参数设置（简化为一个来源）
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8
x_positions = [1, 2, 3]  # 每列在x轴上的位置
plt.figure(figsize=(8, 6))
ax = plt.gca()

# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(3.5, 6)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# 绘制$V_{Ga}-P_O$的电荷转变能级

# %%
# 数据准备（仅保留第一个来源的数据）
data = {
    r"$V_{Ga(I)}-P_{O(I)}$": [7.46707], 
    r"$V_{Ga(I)}-P_{O(II)}$": [8.00681], 
    r"$V_{Ga(I)}-P_{O(III)}$": [7.43211],
    r"$V_{Ga(II)}-P_{O(I)}$": [7.12351], 
    r"$V_{Ga(II)}-P_{O(II)}$": [6.86093], 
    r"$V_{Ga(II)}-P_{O(III)}$": [7.70574],
}

# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(8, 6))
ax = plt.gca()

# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(6.5, 8.5)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# 绘制Fe,Cu体系的费米能级位置图示

# %%
import matplotlib.pyplot as plt

# 带隙边界
vbm = 2.095
cbm = 6.7428

# Cu 系统费米能级
cu_fermi = {
    # "Cu_{Ga(I)}": 2.5483269,
    r"Cu_{Ga(I)}-N_{O(I)}": 3.30103482,
    r"Cu_{Ga(I)}-N_{O(II)}": 3.10870574,
    r"Cu_{Ga(I)}-N_{O(III)}": 3.20575838,
    # "Cu_{Ga(II)}": 2.48227186,
    r"Cu_{Ga(II)}-N_{O(I)}": 3.25484267,
    r"Cu_{Ga(II)}-N_{O(II)}": 2.9982421,
    r"Cu_{Ga(II)}-N_{O(III)}": 3.19749242,
}

# Fe 系统费米能级
fe_fermi = {
    # "Fe_{Ga(I)}": 4.24051661,
    r"Fe_{Ga(I)}-N_{O(I)}": 2.79395556,
    r"Fe_{Ga(I)}-N_{O(II)}": 2.76158213,
    r"Fe_{Ga(I)}-N_{O(III)}": 2.87526427,
    # "Fe_{Ga(II)}": 5.1957575,
    r"Fe_{Ga(II)}-N_{O(I)}": 3.30973125,
    r"Fe_{Ga(II)}-N_{O(II)}": 3.19981624,
    r"Fe_{Ga(II)}-N_{O(III)}": 3.32399148
}

zn_fermi = {
    # "Fe_{Ga(I)}": 4.24051661,
    r"Zn_{Ga(I)}-N_{O(I)}": 2.27933262,
    r"Zn_{Ga(I)}-N_{O(II)}": 1.95970023,
    r"Zn_{Ga(I)}-N_{O(III)}": 2.05850859,
    # "Fe_{Ga(II)}": 5.1957575,
    r"Zn_{Ga(II)}-N_{O(I)}": 2.47872951,
    r"Zn_{Ga(II)}-N_{O(II)}": 2.12562738,
    r"Zn_{Ga(II)}-N_{O(III)}": 2.12650272
}

mg_fermi = {
    # "Fe_{Ga(I)}": 4.24051661,
    r"Zn_{Ga(I)}-N_{O(I)}": 2.1375888,
    r"Zn_{Ga(I)}-N_{O(II)}": 2.13609096,
    r"Zn_{Ga(I)}-N_{O(III)}": 2.11669777,
    # "Fe_{Ga(II)}": 5.1957575,
    r"Zn_{Ga(II)}-N_{O(I)}": 2.36140438,
    r"Zn_{Ga(II)}-N_{O(II)}": 2.13569916,
    r"Zn_{Ga(II)}-N_{O(III)}": 2.13259658
}

positive = {
    r"Cu_{Ga(I)}": 3.09461889,
    r"Cu_{Ga(II)}": 2.4712504,
    r"Fe_{Ga(I)}": 4.09564999,
    r"Fe_{Ga(II)}": 5.19599267,
}

negative = {
    r"N_{O(I)}": 3.76440096,
    r"N_{O(II)}": 2.79819924,
    r"N_{O(III)}": 3.54708723,
    r"P_{O(I)}": 5.6967715,
    r"P_{O(II)}": 4.42877391,
    r"P_{O(III)}": 4.71593688,
    
}
def plot_fermi_levels(fermi_dict, title):
    plt.figure(figsize=(6, 6))
    y_positions = range(len(fermi_dict))
    labels = list(fermi_dict.keys())
    values = list(fermi_dict.values())

    # 绘制费米能级点和文本
    for y, val, label in zip(y_positions, values, labels):
        plt.plot(val, y, 'o', color='blue')
        plt.text(val + 0.05, y, f"{val:.2f} eV", va='center', fontsize=8)

    # 绘制 VBM / CBM 线
    plt.axvline(vbm, color='green', linestyle='--', label=f'VBM = {vbm:.2f} eV')
    plt.axvline(cbm, color='red', linestyle='--', label=f'CBM = {cbm:.2f} eV')

    # 填充价带左侧和导带右侧区域
    plt.axvspan(vbm - 0.5, vbm, color='green', alpha=0.1, label='Valence band')
    plt.axvspan(cbm, cbm + 0.5, color='red', alpha=0.1, label='Conduction band')

    # 图形设置
    plt.yticks(y_positions, labels, fontsize=8)
    plt.xlabel("Energy (eV)")
    plt.title(title)
    plt.xlim(vbm - 0.5, cbm + 0.5)
    plt.ylim(-1, len(fermi_dict))
    plt.legend(loc='upper right')
    plt.grid(axis='x', linestyle=':', alpha=0.5)
    plt.tight_layout()
    plt.show()


# 绘图
plot_fermi_levels(cu_fermi, "Fermi Levels for Cu Doped Systems")
plot_fermi_levels(fe_fermi, "Fermi Levels for Fe Doped Systems")
plot_fermi_levels(positive, "Fermi Levels for Cation Doped Systems")
plot_fermi_levels(negative, "Fermi Levels for Anion Doped Systems")

# %%
import matplotlib.pyplot as plt

# 带隙边界
vbm = 1.984
cbm = 6.0768


zn_fermi = {
    # "Fe_{Ga(I)}": 4.24051661,
    r"Zn_{Ga(I)}-N_{O(I)}": 2.27933262,
    r"Zn_{Ga(I)}-N_{O(II)}": 1.95970023,
    r"Zn_{Ga(I)}-N_{O(III)}": 2.05850859,
    # "Fe_{Ga(II)}": 5.1957575,
    r"Zn_{Ga(II)}-N_{O(I)}": 2.47872951,
    r"Zn_{Ga(II)}-N_{O(II)}": 2.12562738,
    r"Zn_{Ga(II)}-N_{O(III)}": 2.12650272
}

mg_fermi = {
    # "Fe_{Ga(I)}": 4.24051661,
    r"Zn_{Ga(I)}-N_{O(I)}": 2.1375888,
    r"Zn_{Ga(I)}-N_{O(II)}": 2.13609096,
    r"Zn_{Ga(I)}-N_{O(III)}": 2.11669777,
    # "Fe_{Ga(II)}": 5.1957575,
    r"Zn_{Ga(II)}-N_{O(I)}": 2.36140438,
    r"Zn_{Ga(II)}-N_{O(II)}": 2.13569916,
    r"Zn_{Ga(II)}-N_{O(III)}": 2.13259658
}
def plot_fermi_levels(fermi_dict, title):
    plt.figure(figsize=(6, 6))
    y_positions = range(len(fermi_dict))
    labels = list(fermi_dict.keys())
    values = list(fermi_dict.values())

    # 绘制费米能级点和文本
    for y, val, label in zip(y_positions, values, labels):
        plt.plot(val, y, 'o', color='blue')
        plt.text(val + 0.05, y, f"{val:.2f} eV", va='center', fontsize=8)

    # 绘制 VBM / CBM 线
    plt.axvline(vbm, color='green', linestyle='--', label=f'VBM = {vbm:.2f} eV')
    plt.axvline(cbm, color='red', linestyle='--', label=f'CBM = {cbm:.2f} eV')

    # 填充价带左侧和导带右侧区域
    plt.axvspan(vbm - 0.5, vbm, color='green', alpha=0.1, label='Valence band')
    plt.axvspan(cbm, cbm + 0.5, color='red', alpha=0.1, label='Conduction band')

    # 图形设置
    plt.yticks(y_positions, labels, fontsize=8)
    plt.xlabel("Energy (eV)")
    plt.title(title)
    plt.xlim(vbm - 0.5, cbm + 0.5)
    plt.ylim(-1, len(fermi_dict))
    plt.legend(loc='upper right')
    plt.grid(axis='x', linestyle=':', alpha=0.5)
    plt.tight_layout()
    plt.show()


# 绘图
plot_fermi_levels(zn_fermi, "Fermi Levels for Zn Doped Systems")
plot_fermi_levels(mg_fermi, "Fermi Levels for Mg Doped Systems")

# %% [markdown]
# 绘制$Fe_{Ga}-N_O$的电荷转变能级

# %%
# 数据准备（仅保留第一个来源的数据）
data_Fe = {
    r"$Fe_{Ga(I)}-N_{O(I)}$": [3.79919E+00],
    r"$Fe_{Ga(I)}-N_{O(II)}$": [2.93518E+00], 
    r"$Fe_{Ga(I)}-N_{O(III)}$": [3.70702E+00], 
    r"$Fe_{Ga(II)}-N_{O(I)}$": [4.68842E+00],
    r"$Fe_{Ga(II)}-N_{O(II)}$": [4.38269E+00], 
    r"$Fe_{Ga(II)}-N_{O(III)}$": [4.63164E+00], 
}

data = data_Fe

# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(2.5, 5)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# 绘制$Cu_{Ga}-N_O$电荷转变能级

# %%
# 数据准备（仅保留第一个来源的数据）
data_Cu = {
    # r"$Cu_{Ga(I)}$": [2.24102E+00], 
    # r"$Cu_{Ga(II)}$": [4.42301E+00], 
    r"$Cu_{Ga(I)}-N_{O(I)}$": [1.50949E+00],
    r"$Cu_{Ga(I)}-N_{O(II)}$": [9.09080E-01], 
    r"$Cu_{Ga(I)}-N_{O(III)}$": [1.13271E+00], 
    r"$Cu_{Ga(II)}-N_{O(I)}$": [1.34790E+00],
    r"$Cu_{Ga(II)}-N_{O(II)}$": [1.03338E+00], 
    r"$Cu_{Ga(II)}-N_{O(III)}$": [1.27747E+00], 
}

# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

data = data_Cu
# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(0, 2)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
data_Zn = {
    r"$Zn_{Ga(I)}-N_{O(I)}$": [4.04802E+00],
    r"$Zn_{Ga(I)}-N_{O(II)}$": [1.48513E+00], 
    r"$Zn_{Ga(I)}-N_{O(III)}$": [1.80831E+00], 
    r"$Zn_{Ga(II)}-N_{O(I)}$": [4.05045E+00],
    r"$Zn_{Ga(II)}-N_{O(II)}$": [7.71198E-01], 
    r"$Zn_{Ga(II)}-N_{O(III)}$": [1.31217E+00], 
}

# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

data = data_Zn
# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(0, 4.5)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
data_Mg = {
    r"$Mg_{Ga(I)}-N_{O(I)}$": [4.06938E+00],
    r"$Mg_{Ga(I)}-N_{O(II)}$": [1.21825E+00], 
    r"$Mg_{Ga(I)}-N_{O(III)}$": [1.74965E+00], 
    r"$Mg_{Ga(II)}-N_{O(I)}$": [4.06432E+00],
    r"$Mg_{Ga(II)}-N_{O(II)}$": [7.00178E-01], 
    r"$Mg_{Ga(II)}-N_{O(III)}$": [1.29562E+00], 
}
# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

data = data_Mg
# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(0, 4.5)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
data_positive = {
    r"$Cu_{Ga(I)}$": [2.24102E+00],
    r"$Cu_{Ga(II)}$": [2.41894E+00], 
    r"$Fe_{Ga(I)}$": [2.47242E+00], 
    r"$Fe_{Ga(II)}$": [3.40480E+00], 
}
# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, ]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

data = data_positive
# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(0, 4.5)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
data_positive = {
    r"$N_{O(I)}$": [4.09059E+00],
    r"$N_{O(II)}$": [2.96169E+00], 
    r"$N_{O(III)}$": [3.90257E+00], 
    r"$P_{O(I)}$": [5.183243843], 
    r"$P_{O(II)}$": [4.260391122],
    r"$P_{O(III)}$": [4.40719264],
}
# 图形参数设置（简化为一个来源）
x_positions = [1, 2, 3, 4, 5, 6]  # 每列在x轴上的位置
colors = ['#2F5597']  # 仅使用第一个颜色
labels = ['我们的计算结果']  # 仅保留第一个标签
column_width = 0.8

plt.figure(figsize=(12, 9))
ax = plt.gca()

data = data_positive
# 绘制横线（简化循环）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    x_min = x_center - column_width/4
    x_max = x_center + column_width/4
    
    # 只绘制第一个来源的数据
    ax.hlines(y=values[0],  # 取列表中的第一个值
              xmin=x_min,
              xmax=x_max,
              colors=colors[0], 
              linewidth=3, 
              label=labels[0] if idx == 0 else "")

# 坐标轴设置（保持相同范围以维持比例）
ax.set_xticks(x_positions)
ax.set_xticklabels(data.keys(), fontsize=12)
plt.ylabel(r"$\varepsilon(0/-)$ eV", fontsize=12)
plt.ylim(2.5, 6)

# 辅助网格保持原样
ax.grid(axis='y', linestyle='--', alpha=0.7)

# 图例设置（仅显示一个图例）
legend = ax.legend(loc='upper right', 
                  frameon=True,
                  edgecolor='black',
                  fontsize=10)
legend.get_frame().set_facecolor('white')

# 数据标签（仅标注第一个来源）
for idx, (defect, values) in enumerate(data.items()):
    x_center = x_positions[idx]
    ax.text(x_center,  # 居中显示
           values[0] + 0.05, 
           f"{values[0]:.2f} eV", 
           ha='center',
           color=colors[0],
           fontsize=10)

# 美化边框（保持原样）
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
